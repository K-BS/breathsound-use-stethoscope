# %%
import pandas as pd
from pathlib import Path

Catholic_file = 'data/data2.csv'
df = pd.read_csv(Catholic_file)
df
# Out:
#        filename  category  class
# 0    0001-2.wav   healthy      0
# 1    0002-1.wav   healthy      0
# 2    0002-2.wav   healthy      0
# 3    0002-3.wav   healthy      0
# 4    0002-4.wav   healthy      0
# ..          ...       ...    ...
# 258  0614-2.wav  wheezing      1
# 259  0614-3.wav  wheezing      1
# 260  0614-4.wav  wheezing      1
# 261  0615-1.wav  wheezing      1
# 262  0615-2.wav  wheezing      1
#
# [263 rows x 3 columns]

# %%
df['relative_path'] = '/' + df['filename'].astype(str)
df = df[['relative_path', 'class']]
df.head()
# Out:
#   relative_path  class
# 0   /0001-2.wav      0
# 1   /0002-1.wav      0
# 2   /0002-2.wav      0
# 3   /0002-3.wav      0
# 4   /0002-4.wav      0

# %%
import math, random
import torch
import torchaudio
from torchaudio import transforms
from IPython.display import Audio

class Breath_sound_Util():
  
  def open(audio_file):
    sig, sr = torchaudio.load(audio_file)
    return (sig, sr)

  def resample(aud, newsr):
    sig, sr = aud

    if (sr == newsr):
      return aud

    num_channels = sig.shape[0]
    resig = torchaudio.transforms.Resample(sr, newsr)(sig[:1,:])
    if (num_channels > 1):
      retwo = torchaudio.transforms.Resample(sr, newsr)(sig[1:,:])
      resig = torch.cat([resig, retwo])

    return ((resig, newsr))

  def pad(aud, max_ms):
    sig, sr = aud
    num_rows, sig_len = sig.shape
    max_len = sr//1000 * max_ms

    if (sig_len > max_len):
      sig = sig[:,:max_len]

    elif (sig_len < max_len):
      pad_begin_len = random.randint(0, max_len - sig_len)
      pad_end_len = max_len - sig_len - pad_begin_len

      pad_begin = torch.zeros((num_rows, pad_begin_len))
      pad_end = torch.zeros((num_rows, pad_end_len))
        #제로패딩

      sig = torch.cat((pad_begin, sig, pad_end), 1)
      
    return (sig, sr)

  def time_shift(aud, shift_limit):
    sig,sr = aud
    _, sig_len = sig.shape
    shift_amt = int(random.random() * shift_limit * sig_len)
    return (sig.roll(shift_amt), sr)

  def spectro_gram(aud, n_mels=64, n_fft=1024, hop_len=None):
    sig,sr = aud
    top_db = 80

    spec = transforms.MelSpectrogram(sr, n_fft=n_fft, hop_length=hop_len, n_mels=n_mels)(sig)

    spec = transforms.AmplitudeToDB(top_db=top_db)(spec)
    return (spec)

  def spectro_augment(spec, max_mask_pct=0.1, n_freq_masks=1, n_time_masks=1):
    _, n_mels, n_steps = spec.shape
    mask_value = spec.mean()
    aug_spec = spec

    freq_mask_param = max_mask_pct * n_mels
    for _ in range(n_freq_masks):
      aug_spec = transforms.FrequencyMasking(freq_mask_param)(aug_spec, mask_value)

    time_mask_param = max_mask_pct * n_steps
    for _ in range(n_time_masks):
      aug_spec = transforms.TimeMasking(time_mask_param)(aug_spec, mask_value)

    return aug_spec

# %%
data_path = 'data/all_data'

# %%
from torch.utils.data import DataLoader, Dataset, random_split
import torchaudio

class breathDS(Dataset):
    
  def __init__(self, df, data_path):
    self.df = df
    self.data_path = str(data_path)
    self.duration = 4000
    self.sr = 48000
    self.channel = 2
    self.shift_pct = 0.4
            
  def __len__(self):
    return len(self.df)    
    
  def __getitem__(self, idx):
    audio_file = self.data_path + self.df.loc[idx, 'relative_path']
    class_id = self.df.loc[idx, 'class']
    aud = Breath_sound_Util.open(audio_file)
    reaud = Breath_sound_Util.resample(aud, self.sr)
    dur_aud = Breath_sound_Util.pad(reaud, self.duration)
    shift_aud = Breath_sound_Util.time_shift(dur_aud, self.shift_pct)
    sgram = Breath_sound_Util.spectro_gram(shift_aud, n_mels=64, n_fft=1024, hop_len=None)
    aug_sgram = Breath_sound_Util.spectro_augment(sgram, max_mask_pct=0.1, n_freq_masks=2, n_time_masks=2)

    return aug_sgram, class_id

# %%
from torch.utils.data import random_split

brds = breathDS(df, data_path)

# %%
num_items = len(brds)
num_train = round(num_items * 0.8)
num_val = num_items - num_train
train_ds, val_ds = random_split(brds, [num_train, num_val])

# Create training and validation data loaders
train_dl = torch.utils.data.DataLoader(train_ds, batch_size=16, shuffle=True)
val_dl = torch.utils.data.DataLoader(val_ds, batch_size=16, shuffle=True)

# %%
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import init

# --------------------------------------------------------------
# 호흡음의 Healthy, Wheezing을 판단하는 Binary Classification Model
# --------------------------------------------------------------

class WhoWheezing(nn.Module):

    def __init__(self):
        super().__init__()
        conv_layers = []
        self.conv1 = nn.Conv2d(1, 8, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
        self.relu1 = nn.ReLU()
        self.bn1 = nn.BatchNorm2d(8)
        init.kaiming_normal_(self.conv1.weight, a=0.1)
        self.conv1.bias.data.zero_()
        conv_layers += [self.conv1, self.relu1, self.bn1]

        self.conv2 = nn.Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
        self.relu2 = nn.ReLU()
        self.bn2 = nn.BatchNorm2d(16)
        init.kaiming_normal_(self.conv2.weight, a=0.1)
        self.conv2.bias.data.zero_()
        conv_layers += [self.conv2, self.relu2, self.bn2]

        self.conv3 = nn.Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
        self.relu3 = nn.ReLU()
        self.bn3 = nn.BatchNorm2d(32)
        init.kaiming_normal_(self.conv3.weight, a=0.1)
        self.conv3.bias.data.zero_()
        conv_layers += [self.conv3, self.relu3, self.bn3]

        self.conv4 = nn.Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
        self.relu4 = nn.ReLU()
        self.bn4 = nn.BatchNorm2d(64)
        init.kaiming_normal_(self.conv4.weight, a=0.1)
        self.conv4.bias.data.zero_()
        conv_layers += [self.conv4, self.relu4, self.bn4]

        self.ap = nn.AdaptiveAvgPool2d(output_size=1)
        self.lin = nn.Linear(in_features=64, out_features=2)
        self.sigmoid = nn.Sigmoid()

        self.conv = nn.Sequential(*conv_layers)
 
    def forward(self, x):
        x = self.conv(x)
        x = self.ap(x)
        x = x.view(x.shape[0], -1)
        x = self.lin(x)
        x = self.sigmoid(x)
        return x

Model1 = WhoWheezing()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
Model1 = Model1.to(device)
next(Model1.parameters()).device
# Out:
# device(type='cuda', index=0)

# %%
def training(model, train_dl, num_epochs):
  criterion = nn.CrossEntropyLoss()
  optimizer = torch.optim.Adam(model.parameters(),lr=0.001)
  scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.001,
                                                steps_per_epoch=int(len(train_dl)),
                                                epochs=num_epochs,
                                                anneal_strategy='linear')

  for epoch in range(num_epochs):
    running_loss = 0.0
    correct_prediction = 0
    total_prediction = 0

    for i, data in enumerate(train_dl):
        inputs, labels = data[0].to(device), data[1].to(device)
        inputs_m, inputs_s = inputs.mean(), inputs.std()
        inputs = (inputs - inputs_m) / inputs_s
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        scheduler.step()
        running_loss += loss.item()
        _, prediction = torch.max(outputs,1)
        correct_prediction += (prediction == labels).sum().item()
        total_prediction += prediction.shape[0]

    num_batches = len(train_dl)
    avg_loss = running_loss / num_batches
    acc = correct_prediction/total_prediction
    print(f'Epoch: {epoch}, Loss: {avg_loss:.4f}, Accuracy: {acc:.4f}')

  print('Finished Training')
  
num_epochs=100
training(Model1, train_dl, num_epochs)
# Out:
# Epoch: 0, Loss: 0.6860, Accuracy: 0.6048
# Epoch: 1, Loss: 0.6679, Accuracy: 0.7905
# Epoch: 2, Loss: 0.6370, Accuracy: 0.8714
# Epoch: 3, Loss: 0.6059, Accuracy: 0.8714
# Epoch: 4, Loss: 0.5631, Accuracy: 0.8571
# Epoch: 5, Loss: 0.5412, Accuracy: 0.8381
# Epoch: 6, Loss: 0.5317, Accuracy: 0.8667
# Epoch: 7, Loss: 0.5058, Accuracy: 0.8381
# Epoch: 8, Loss: 0.5244, Accuracy: 0.8238
# Epoch: 9, Loss: 0.5109, Accuracy: 0.8381
# Epoch: 10, Loss: 0.5043, Accuracy: 0.8524
# Epoch: 11, Loss: 0.4864, Accuracy: 0.8524
# Epoch: 12, Loss: 0.4747, Accuracy: 0.8476
# Epoch: 13, Loss: 0.4816, Accuracy: 0.8810
# Epoch: 14, Loss: 0.4976, Accuracy: 0.8571
# Epoch: 15, Loss: 0.4699, Accuracy: 0.8762
# Epoch: 16, Loss: 0.4434, Accuracy: 0.8952
# Epoch: 17, Loss: 0.4360, Accuracy: 0.8905
# Epoch: 18, Loss: 0.4603, Accuracy: 0.8857
# Epoch: 19, Loss: 0.4203, Accuracy: 0.9048
# Epoch: 20, Loss: 0.4691, Accuracy: 0.8762
# Epoch: 21, Loss: 0.4601, Accuracy: 0.8857
# Epoch: 22, Loss: 0.4266, Accuracy: 0.8905
# Epoch: 23, Loss: 0.4356, Accuracy: 0.9000
# Epoch: 24, Loss: 0.4336, Accuracy: 0.8619
# Epoch: 25, Loss: 0.4616, Accuracy: 0.8762
# Epoch: 26, Loss: 0.4509, Accuracy: 0.8857
# Epoch: 27, Loss: 0.4534, Accuracy: 0.8952
# Epoch: 28, Loss: 0.4370, Accuracy: 0.8905
# Epoch: 29, Loss: 0.4608, Accuracy: 0.8810
# Epoch: 30, Loss: 0.4720, Accuracy: 0.8571
# Epoch: 31, Loss: 0.4165, Accuracy: 0.8952
# Epoch: 32, Loss: 0.4364, Accuracy: 0.8905
# Epoch: 33, Loss: 0.4426, Accuracy: 0.8857
# Epoch: 34, Loss: 0.4423, Accuracy: 0.8857
# Epoch: 35, Loss: 0.4462, Accuracy: 0.9048
# Epoch: 36, Loss: 0.4105, Accuracy: 0.9048
# Epoch: 37, Loss: 0.4377, Accuracy: 0.8857
# Epoch: 38, Loss: 0.4268, Accuracy: 0.8952
# Epoch: 39, Loss: 0.4142, Accuracy: 0.9000
# Epoch: 40, Loss: 0.4290, Accuracy: 0.8952
# Epoch: 41, Loss: 0.4070, Accuracy: 0.9048
# Epoch: 42, Loss: 0.4315, Accuracy: 0.9143
# Epoch: 43, Loss: 0.4397, Accuracy: 0.9048
# Epoch: 44, Loss: 0.3981, Accuracy: 0.9143
# Epoch: 45, Loss: 0.4382, Accuracy: 0.9048
# Epoch: 46, Loss: 0.4490, Accuracy: 0.8905
# Epoch: 47, Loss: 0.4352, Accuracy: 0.9048
# Epoch: 48, Loss: 0.4465, Accuracy: 0.8952
# Epoch: 49, Loss: 0.4061, Accuracy: 0.9000
# Epoch: 50, Loss: 0.4070, Accuracy: 0.9048
# Epoch: 51, Loss: 0.4177, Accuracy: 0.9000
# Epoch: 52, Loss: 0.4342, Accuracy: 0.9048
# Epoch: 53, Loss: 0.4130, Accuracy: 0.9095
# Epoch: 54, Loss: 0.4260, Accuracy: 0.8905
# Epoch: 55, Loss: 0.4345, Accuracy: 0.9048
# Epoch: 56, Loss: 0.4099, Accuracy: 0.8952
# Epoch: 57, Loss: 0.4124, Accuracy: 0.9048
# Epoch: 58, Loss: 0.4267, Accuracy: 0.8952
# Epoch: 59, Loss: 0.4042, Accuracy: 0.9143
# Epoch: 60, Loss: 0.4082, Accuracy: 0.8905
# Epoch: 61, Loss: 0.4066, Accuracy: 0.9048
# Epoch: 62, Loss: 0.3985, Accuracy: 0.9143
# Epoch: 63, Loss: 0.3968, Accuracy: 0.9190
# Epoch: 64, Loss: 0.4343, Accuracy: 0.8952
# Epoch: 65, Loss: 0.4102, Accuracy: 0.9190
# Epoch: 66, Loss: 0.4182, Accuracy: 0.9000
# Epoch: 67, Loss: 0.4517, Accuracy: 0.9000
# Epoch: 68, Loss: 0.4159, Accuracy: 0.9048
# Epoch: 69, Loss: 0.4284, Accuracy: 0.9095
# Epoch: 70, Loss: 0.4057, Accuracy: 0.9143
# Epoch: 71, Loss: 0.4339, Accuracy: 0.8905
# Epoch: 72, Loss: 0.4177, Accuracy: 0.9000
# Epoch: 73, Loss: 0.4040, Accuracy: 0.9143
# Epoch: 74, Loss: 0.4000, Accuracy: 0.9048
# Epoch: 75, Loss: 0.4061, Accuracy: 0.9000
# Epoch: 76, Loss: 0.4595, Accuracy: 0.8952
# Epoch: 77, Loss: 0.4205, Accuracy: 0.9048
# Epoch: 78, Loss: 0.4126, Accuracy: 0.9095
# Epoch: 79, Loss: 0.4037, Accuracy: 0.9143
# Epoch: 80, Loss: 0.4500, Accuracy: 0.9000
# Epoch: 81, Loss: 0.3987, Accuracy: 0.9048
# Epoch: 82, Loss: 0.4050, Accuracy: 0.9048
# Epoch: 83, Loss: 0.4203, Accuracy: 0.9048
# Epoch: 84, Loss: 0.4134, Accuracy: 0.9000
# Epoch: 85, Loss: 0.4384, Accuracy: 0.9000
# Epoch: 86, Loss: 0.4026, Accuracy: 0.9190
# Epoch: 87, Loss: 0.4129, Accuracy: 0.9143
# Epoch: 88, Loss: 0.4661, Accuracy: 0.9000
# Epoch: 89, Loss: 0.3974, Accuracy: 0.9143
# Epoch: 90, Loss: 0.3981, Accuracy: 0.9190
# Epoch: 91, Loss: 0.4126, Accuracy: 0.9143
# Epoch: 92, Loss: 0.4188, Accuracy: 0.9190
# Epoch: 93, Loss: 0.4349, Accuracy: 0.9048
# Epoch: 94, Loss: 0.4046, Accuracy: 0.9143
# Epoch: 95, Loss: 0.4626, Accuracy: 0.8952
# Epoch: 96, Loss: 0.4050, Accuracy: 0.9095
# Epoch: 97, Loss: 0.3996, Accuracy: 0.9095
# Epoch: 98, Loss: 0.4215, Accuracy: 0.9143
# Epoch: 99, Loss: 0.4309, Accuracy: 0.9143
# Finished Training
